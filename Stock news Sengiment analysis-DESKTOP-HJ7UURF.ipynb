# %%
import newsapi
import pandas as pd
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer 
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\boston\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
client=newsapi.NewsApiClient(api_key='a71d8be2e322412aa9bb917361675f4c')

# %%
sources = client.get_sources()

# %%
sources
# Out:
# {'status': 'ok',
#  'sources': [{'id': 'abc-news',
#    'name': 'ABC News',
#    'description': 'Your trusted source for breaking news, analysis, exclusive interviews, headlines, and videos at ABCNews.com.',
#    'url': 'https://abcnews.go.com',
#    'category': 'general',
#    'language': 'en',
#    'country': 'us'},
#   {'id': 'abc-news-au',
#    'name': 'ABC News (AU)',
#    'description': "Australia's most trusted source of local, national and world news. Comprehensive, independent, in-depth analysis, the latest business, sport, weather and more.",
#    'url': 'http://www.abc.net.au/news',
#    'category': 'general',
#    'language': 'en',
#    'country': 'au'},
#   {'id': 'aftenposten',
#    'name': 'Aftenposten',
#    'description': 'Norges ledende nettavis med alltid oppdaterte nyheter innenfor innenriks, utenriks, sport og kultur.',
#    'url': 'https://www.aftenposten.no',
#    'category': 'general',
#    'language': 'no',
#    'country': 'no'},
# ...

# %%
all_articles = client.get_everything(q='lending rate' and 'SBI',
                                     sources='the-hindu',
                                      domains='http://www.thehindu.com',
                                      from_param='2019-11-15',
                                      to='2019-12-11',
                                      language='en')

# %%
all_articles
# Out:
# {'status': 'ok',
#  'totalResults': 65,
#  'articles': [{'source': {'id': 'the-hindu', 'name': 'The Hindu'},
#    'author': 'PTI',
#    'title': 'AIIMS loses over ₹12 cr. in bank fraud',
#    'description': 'SBI issues alert to all its branches',
#    'url': 'https://www.thehindu.com/news/national/aiims-loses-over-12-cr-in-bank-fraud/article30121854.ece',
#    'urlToImage': 'https://www.thehindu.com/static/theme/default/base/img/og-image.jpg',
#    'publishedAt': '2019-11-30T03:50:37Z',
#    'content': 'Indias premier medical institute All India Institute of Medical Sciences (AIIMS) fell prey to a banking fraud as over 12 crore has been stolen from its two bank accounts with the SBI by allegedly using cloned cheques over the past one month. The money has bee… [+2770 chars]'},
#   {'source': {'id': 'the-hindu', 'name': 'The Hindu'},
#    'author': 'Special Correspondent',
#    'title': 'SBI brings down lending rate by 10 bps',
# ...

# %%
import pandas as pd
content=[]
date=[]
for i in range(len(all_articles['articles'])):
    extract=all_articles['articles'][i]
    content.append(extract['content'])
    date.append(extract['publishedAt'])

# %%
import pandas as pd
content=[]
date=[]
for i in range(len(all_articles['articles'])):
    extract=all_articles['articles'][i]
    content.append(extract['content'])
    date.append(extract['publishedAt'])
news_data=pd.DataFrame(data={'content':content,'date':date})

# %%
news_data.head()
# Out:
#                                              content                  date
# 0  Chief Minister V. Narayanasamy on Friday calle...  2019-11-15T18:30:29Z
# 1  State Bank of India, the countrys largest lend...  2019-12-09T16:21:48Z
# 2  Interest on home loan\r\nQ. My wife and I are ...  2019-12-08T11:45:26Z
# 3  Many people today wish to own their dream home...  2019-11-25T14:12:32Z
# 4  Vadde Polamma, 50, a daily wage earner along w...  2019-12-01T07:26:48Z

# %%
for i in news_data['content']:
    print(str(i))

# %%
ss=[]
sid = SentimentIntensityAnalyzer()
for sentence in news_data['content']:
     print(sentence)
     ss.append(sid.polarity_scores(str(sentence)))

# %%
ss

# %%
sentiment=pd.DataFrame(data=ss)

# %%
sentiment.head()

# %%
from ipywidgets import interact, interactive
import ipywidgets as widgets

# %%
company_name=widgets.Dropdown(options=['apple','Tesla','microsoft'],value='apple',description='company name:')
sources_name=widgets.Dropdown(options=['bloomberg','business-insider'],value='bloomberg',description='sources')
domains_name=widgets.Dropdown(options=['http://www.bloomberg.com','http://www.businessinsider.com'],value='http://www.bloomberg.com',description='domains name:')

# %%
ui=widgets.HBox((company_name,sources_name,domains_name))

# %%
def news_options(company,sources,domains):
    all_articles = client.get_everything(q=company,
                                     sources=sources,
                                      domains=domains,
                                      from_param='2019-05-20',
                                      to='2019-06-11',
                                      language='en')
    content=[]
    date=[]
    for i in range(len(all_articles['articles'])):
        extract=all_articles['articles'][i]
        content.append(extract['content'])
        date.append(extract['publishedAt'])
    news_data=pd.DataFrame(data={'content':content,'date':date})
    ss=[]
    sid = SentimentIntensityAnalyzer()
    for sentence in news_data['content']:
        ss.append(sid.polarity_scores(str(sentence)))
    sentiment=pd.DataFrame(data=ss)
    print(sentiment.head(20))
    return sentiment

# %%
out=widgets.interactive_output(news_options,{'company':company_name,'sources':sources_name,'domains':domains_name})
display(ui,out)

# %%
out.
